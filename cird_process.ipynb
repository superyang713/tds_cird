# %%
from LittleMachine_TDS_Lib import CIRD
# %matplotlib notebook

# %%
cird = CIRD("nov17_17.c01")

# %%
cird.load_data(show_plot=True)

# %%
cird.data.head()
# Out:
#    counts    temp  time
# 0  5970.0  72.818   0.0
# 1  5940.0  72.831   0.2
# 2  5995.0  72.888   0.4
# 3  5995.0  72.933   0.6
# 4  6040.0  72.831   0.8

# %%
cird.level_background()
# Out:
# Estimated beam stop time: 265
# Please enter the sensitivity factor:1.3

# %%
cird.data.head()
# Out:
#    counts    temp  time  counts_leveled_background
# 0  5970.0  72.818   0.0                -237.696121
# 1  5940.0  72.831   0.2                -271.762136
# 2  5995.0  72.888   0.4                -209.359690
# 3  5995.0  72.933   0.6                -209.378013
# 4  6040.0  72.831   0.8                -158.324798

# %%
cird.peak_fit(area_high=False)
# Out:
# [  9.56612507e+01   3.20641563e+02  -1.68897276e-01  -3.34315638e-02
#    1.19613445e+02   1.33045528e+02   6.05910314e+01]
# 105.6

# %%
cird.create_plot(area_high=False)

# %%
cird.data.head()
# Out:
#    counts    temp  time  counts_leveled_background  exponential_fit
# 0  3390.0  71.900   0.0                 304.411005              0.0
# 1  3420.0  71.881   0.2                 363.355675              0.0
# 2  3505.0  71.959   0.4                 530.742146              0.0
# 3  3520.0  71.746   0.6                 560.111779              0.0
# 4  3470.0  71.926   0.8                 461.322920              0.0

# %%
cird.write_file()
# Out:
# Do you want to save the data to pdec20_17.c01? (Y/N): y
# Success!
