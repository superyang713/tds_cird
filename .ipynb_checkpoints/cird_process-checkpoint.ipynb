# %%
# from LittleMachine_TDS_Lib import CIRD
# %matplotlib notebook

# %%
cird = CIRD("nov28_17.c01")

# %%
cird.load_data(show_plot=True)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
cird.data.head()
# Out:
#    counts    temp  time
# 0  6575.0  72.645   0.0
# 1  6650.0  71.798   0.2
# 2  6735.0  72.195   0.4
# 3  6730.0  71.939   0.6
# 4  6585.0  72.054   0.8

# %%
cird.level_background()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/qingliu/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     718             try:
# --> 719                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     720             except Exception:
#
# /Users/qingliu/anaconda/envs/py35/lib/python3.5/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     738         try:
# --> 739             msg_list = socket.recv_multipart(mode, copy=copy)
#     740         except zmq.ZMQError as e:
#
# /Users/qingliu/anaconda/envs/py35/lib/python3.5/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2344)()
#
# /Users/qingliu/anaconda/envs/py35/lib/python3.5/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ed87578298e9> in <module>()
# ----> 1 cird.level_background()
#
# /Users/qingliu/Dropbox (MIT)/littlemachine/PythonCode/TDS_CIRD/LittleMachine_TDS_Lib.py in level_background(self, npts)
#     409         self.index_beamstart = np.argmax(np.diff(self.data["counts"]))+1
#     410         self.time_beamstart = self.data["time"].iloc[self.index_beamstart]
# --> 411         self.time_beamstop = float(input("Estimated beam stop time: "))
#     412         self.index_beamstop = int(self.time_beamstop * 5)
#     413         X = pd.concat(
#
# /Users/qingliu/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     692             self._parent_ident,
#     693             self._parent_header,
# --> 694             password=False,
#     695         )
#     696
#
# /Users/qingliu/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     722             except KeyboardInterrupt:
#     723                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 724                 raise KeyboardInterrupt
#     725             else:
#     726                 break
#
# KeyboardInterrupt:

# %%
cird.data.head()

# %%
cird.peak_fit(area_high=False)

# %%
cird.create_plot(area_high=False)
# Out:
# /home/yang/Environments/data_process_ENV/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
cird.data.head()
# Out:
#    counts    temp  time  counts_leveled_background  exponential_fit
# 0  6575.0  72.645   0.0                 407.459135              0.0
# 1  6650.0  71.798   0.2                 481.989055              0.0
# 2  6735.0  72.195   0.4                 566.518975              0.0
# 3  6730.0  71.939   0.6                 561.048895              0.0
# 4  6585.0  72.054   0.8                 415.578816              0.0

# %%
cird.write_file()
# Out:
# Do you want to save the data to pnov28_17.c01? (Y/N): y
# Success!
